# %% [markdown]
# # Run BIDS App Template on a Flywheel Instance

# %% [markdown]
# The cell below will get a Flywheel client if you are logged in to a Flywheel instance.  It prints out the URL of the instance so you know where you are logged in.

# %%
from datetime import datetime
import flywheel
fw = flywheel.Client('')
fw.get_config().site.api_url
# Out:
# 'https://ss.ce.flywheel.io:443/api'

# %% [markdown]
# Edit these constants to fit your situation.  The ID for the subject can be copied from the URL of a subject when you select it using the Flywheel platform.  This example runs the gear on a subject (as opposed to a project or session).  The Freesurfer license in set in the project's "FREESURFER_LICENSE" Custom Information.  This runs the gear at the subject level.

# %%
GEAR_NAME = "bids-app-template"
SUBJECT = "5dc091c269d4f3002d16f334"

# %%
gear = fw.lookup(f"gears/{GEAR_NAME}")
gear.gear.version
# Out:
# '0.0.0_0.3.15'

# %%
subject = fw.get_subject(SUBJECT)
subject.label
# Out:
# 'sub-TOME3024'

# %%
inputs = {}

config = {
    "bids_app_args": "",
    "example-bool-param": False,
    "example-empty-param": "",
    "example-threshold": 3.1415926,
    "gear-dry-run": False,
    "gear-ignore-bids-errors": False,
    "gear-intermediate-files": "",
    "gear-intermediate-folders": "",
    "gear-keep-output": False,
    "gear-log-level": "INFO",
    "gear-run-bids-validation": True,
    "gear-save-intermediate-output": False,
    "verbose": "v",
    "write-graph": False
}

now = datetime.now()
analysis_label = f'{gear.gear.name} {now.strftime("%m-%d-%Y %H:%M:%S")} SDK launched'

analysis_id = gear.run(analysis_label=analysis_label, config=config, inputs=inputs, destination=subject)

# %%
def show_job_info(analysis_id):
    now = datetime.now()
    print(f'{now.strftime("%m-%d-%Y %H:%M:%S")}')
    print(f'analysis_id = {analysis_id}')
    analysis = fw.get_analysis(analysis_id)
    print(f'analysis.label = {analysis.label}')
    job_id = analysis.job.id
    print(f'job_id = {job_id}')
    job = fw.get_job(job_id)
    print(f'job.gear_info = {job.gear_info}')
    print(f'job.state = {job.state}')
    print(f'job.transitions = {job.transitions}')

# %%
show_job_info(analysis_id)
# Out:
# 11-19-2020 17:54:55
# analysis_id = 5fb6f7a8b116da9bc035f134
# analysis.label = bids-app-template 11-19-2020 17:54:32 SDK launched
# job_id = 5fb6f7a8b116da9bc035f135
# job.gear_info = {'category': 'analysis',
#  'id': None,
#  'name': 'bids-app-template',
#  'version': '0.0.0_0.3.15'}
# job.state = running
# job.transitions = {'cancelled': None,
#  'complete': None,
#  'failed': None,
#  'running': datetime.datetime(2020, 11, 19, 22, 54, 35, 321000, tzinfo=tzutc())}

# %%
show_job_info(analysis_id)
# Out:
# 11-19-2020 17:56:35
# analysis_id = 5fb6f7a8b116da9bc035f134
# analysis.label = bids-app-template 11-19-2020 17:54:32 SDK launched
# job_id = 5fb6f7a8b116da9bc035f135
# job.gear_info = {'category': 'analysis',
#  'id': None,
#  'name': 'bids-app-template',
#  'version': '0.0.0_0.3.15'}
# job.state = complete
# job.transitions = {'cancelled': None,
#  'complete': datetime.datetime(2020, 11, 19, 22, 54, 57, 485000, tzinfo=tzutc()),
#  'failed': None,
#  'running': datetime.datetime(2020, 11, 19, 22, 54, 35, 321000, tzinfo=tzutc())}

# %%
job_id = "5fb6f7a8b116da9bc035f135"
detail = fw.get_job_detail(job_id)
detail
# Out:
# {'attempt': 1,
#  'config': {'config': {'bids_app_args': '',
#                        'example-bool-param': False,
#                        'example-empty-param': '',
#                        'example-threshold': 3.1415926,
#                        'gear-dry-run': False,
#                        'gear-ignore-bids-errors': False,
#                        'gear-intermediate-files': '',
#                        'gear-intermediate-folders': '',
#                        'gear-keep-output': False,
#                        'gear-log-level': 'INFO',
#                        'gear-run-bids-validation': True,
#                        'gear-save-intermediate-output': False,
#                        'verbose': 'v',
#                        'write-graph': False},
#             'destination': {'id': '5fb6f7a8b116da9bc035f134',
#                             'type': 'analysis'},
#             'inputs': {}},
#  'created': datetime.datetime(2020, 11, 19, 22, 54, 32, 950000, tzinfo=tzutc()),
#  'destination': {'id': '5fb6f7a8b116da9bc035f134', 'type': 'analysis'},
#  'gear_id': '5fb5a2f270bdffa34535f17a',
#  'gear_info': {'category': 'analysis',
#                'id': None,
#                'name': 'bids-app-template',
#                'version': '0.0.0_0.3.15'},
#  'id': '5fb6f7a8b116da9bc035f135',
#  'inputs': {},
#  'modified': datetime.datetime(2020, 11, 19, 22, 54, 57, 485000, tzinfo=tzutc()),
#  'origin': {'id': 'andyworth@flywheel.io', 'type': 'user'},
#  'outputs': [{'object': {'classification': {},
#                          'created': datetime.datetime(2020, 11, 19, 22, 54, 55, 797000, tzinfo=tzutc()),
#                          'hash': 'v0-sha384-3ae3a014fe59f623ca9f9581376128a9435c2cc82f4c91d944da3a3b4251f95d5f3765fd9cb27e56e4483ffe8a125a49',
#                          'id': '7e834159-eeda-4eb5-8d7d-973ddd369948',
#                          'info': None,
#                          'info_exists': None,
#                          'mimetype': 'application/zip',
#                          'modality': None,
#                          'modified': datetime.datetime(2020, 11, 19, 22, 54, 55, 797000, tzinfo=tzutc()),
#                          'name': 'index_5fb6f7a8b116da9bc035f134.html.zip',
#                          'origin': {'id': '5fb6f7a8b116da9bc035f135',
#                                     'method': None,
#                                     'name': None,
#                                     'type': 'job',
#                                     'via': None},
#                          'replaced': None,
#                          'size': 727,
#                          'tags': [],
#                          'type': 'archive',
#                          'zip_member_count': None},
#               'ref': {'id': '5fb6f7a8b116da9bc035f134',
#                       'name': 'index_5fb6f7a8b116da9bc035f134.html.zip',
#                       'type': 'analysis'}},
#              {'object': {'classification': {},
#                          'created': datetime.datetime(2020, 11, 19, 22, 54, 55, 797000, tzinfo=tzutc()),
#                          'hash': 'v0-sha384-8f7f70b80d14b1e99ef7fc6980758a0c3829b9ae920a289294922b3b0be34f984a6e11a82539c630a4f771893d69a2fd',
#                          'id': '489e3203-c304-482c-87ff-f1f964c038b4',
#                          'info': None,
#                          'info_exists': None,
#                          'mimetype': 'application/zip',
#                          'modality': None,
#                          'modified': datetime.datetime(2020, 11, 19, 22, 54, 55, 797000, tzinfo=tzutc()),
#                          'name': 'bids-app-template_sub-TOME3024_5fb6f7a8b116da9bc035f134.zip',
#                          'origin': {'id': '5fb6f7a8b116da9bc035f135',
#                                     'method': None,
#                                     'name': None,
#                                     'type': 'job',
#                                     'via': None},
#                          'replaced': None,
#                          'size': 3354,
#                          'tags': [],
#                          'type': 'archive',
#                          'zip_member_count': None},
#               'ref': {'id': '5fb6f7a8b116da9bc035f134',
#                       'name': 'bids-app-template_sub-TOME3024_5fb6f7a8b116da9bc035f134.zip',
#                       'type': 'analysis'}},
#              {'object': {'classification': {},
#                          'created': datetime.datetime(2020, 11, 19, 22, 54, 55, 797000, tzinfo=tzutc()),
#                          'hash': 'v0-sha384-6edbdd7fa3f0948d995ad4893f88f2d70c7e19d71bd579ac69b5432ca0f2fbf0f47690d64bfef7804ac9284fb60f003c',
#                          'id': '765a4a12-65f7-48ba-853c-1c69a9bc3251',
#                          'info': None,
#                          'info_exists': None,
#                          'mimetype': 'text/html',
#                          'modality': None,
#                          'modified': datetime.datetime(2020, 11, 19, 22, 54, 55, 797000, tzinfo=tzutc()),
#                          'name': 'bids_tree.html',
#                          'origin': {'id': '5fb6f7a8b116da9bc035f135',
#                                     'method': None,
#                                     'name': None,
#                                     'type': 'job',
#                                     'via': None},
#                          'replaced': None,
#                          'size': 1527,
#                          'tags': [],
#                          'type': 'markup',
#                          'zip_member_count': None},
#               'ref': {'id': '5fb6f7a8b116da9bc035f134',
#                       'name': 'bids_tree.html',
#                       'type': 'analysis'}},
#              {'object': {'classification': {},
#                          'created': datetime.datetime(2020, 11, 19, 22, 54, 55, 797000, tzinfo=tzutc()),
#                          'hash': 'v0-sha384-3ae3a014fe59f623ca9f9581376128a9435c2cc82f4c91d944da3a3b4251f95d5f3765fd9cb27e56e4483ffe8a125a49',
#                          'id': '6241b17c-c153-48bf-bd97-a44998946a42',
#                          'info': None,
#                          'info_exists': None,
#                          'mimetype': 'application/zip',
#                          'modality': None,
#                          'modified': datetime.datetime(2020, 11, 19, 22, 54, 55, 797000, tzinfo=tzutc()),
#                          'name': 'bids_tree_5fb6f7a8b116da9bc035f134.html.zip',
#                          'origin': {'id': '5fb6f7a8b116da9bc035f135',
#                                     'method': None,
#                                     'name': None,
#                                     'type': 'job',
#                                     'via': None},
#                          'replaced': None,
#                          'size': 727,
#                          'tags': [],
#                          'type': 'archive',
#                          'zip_member_count': None},
#               'ref': {'id': '5fb6f7a8b116da9bc035f134',
#                       'name': 'bids_tree_5fb6f7a8b116da9bc035f134.html.zip',
#                       'type': 'analysis'}}],
#  'parent_info': {'acquisition': None,
#                  'analysis': {'id': '5fb6f7a8b116da9bc035f134',
#                               'label': 'bids-app-template 11-19-2020 17:54:32 '
#                                        'SDK launched'},
#                  'group': {'id': 'scien', 'label': 'Scientific Solutions'},
#                  'project': {'id': '5dc091c169d4f3002d16f32f',
#                              'label': 'BIDS_multi_session'},
#                  'session': None,
#                  'subject': {'id': '5dc091c269d4f3002d16f334',
#                              'label': 'sub-TOME3024'}},
#  'previous_job_id': None,
#  'request': {'inputs': [{'location': '/',
#                          'type': 'docker',
#                          'uri': 'ss.ce.flywheel.io/bids-app-template@sha256:e9fba368072e98e74d21a57e3ce584766f3a220c5add0528ba3bc804312bf8ff',
#                          'vu': None},
#                         {'location': '/flywheel/v0',
#                          'type': 'scitran',
#                          'uri': '/jobs/5fb6f7a8b116da9bc035f135/config.json',
#                          'vu': None}],
#              'outputs': [{'location': '/flywheel/v0/output',
#                           'type': 'scitran',
#                           'uri': '/engine?level=analysis&id=5fb6f7a8b116da9bc035f134&job=5fb6f7a8b116da9bc035f135'}],
#              'target': {'command': ['bash',
#                                     '-c',
#                                     '/usr/local/miniconda/bin/python run.py'],
#                         'dir': '/flywheel/v0',
#                         'env': {'FW_CONFIG_BIDS_APP_ARGS': '',
#                                 'FW_CONFIG_EXAMPLEBOOLPARAM': 'false',
#                                 'FW_CONFIG_EXAMPLEEMPTYPARAM': '',
#                                 'FW_CONFIG_EXAMPLETHRESHOLD': '3.1415926',
#                                 'FW_CONFIG_GEARDRYRUN': 'false',
#                                 'FW_CONFIG_GEARIGNOREBIDSERRORS': 'false',
#                                 'FW_CONFIG_GEARINTERMEDIATEFILES': '',
#                                 'FW_CONFIG_GEARINTERMEDIATEFOLDERS': '',
#                                 'FW_CONFIG_GEARKEEPOUTPUT': 'false',
#                                 'FW_CONFIG_GEARLOGLEVEL': 'INFO',
#                                 'FW_CONFIG_GEARRUNBIDSVALIDATION': 'true',
#                                 'FW_CONFIG_GEARSAVEINTERMEDIATEOUTPUT': 'false',
#                                 'FW_CONFIG_VERBOSE': 'v',
#                                 'FW_CONFIG_WRITEGRAPH': 'false',
#                                 'PATH': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin',
#                                 'PYTHONUNBUFFERED': '1'}}},
#  'retried': None,
#  'state': 'complete',
#  'tags': ['analysis', 'bids-app-template']}

# %%
job_logs = fw.get_job_logs(job_id)
job_logs
# Out:
# {'id': None,
#  'logs': [{'fd': -1,
#            'msg': 'Gear Name: bids-app-template, Gear Version: 0.0.0_0.3.15\n'},
#           {'fd': -1, 'msg': 'Gear starting...\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO flywheel_gear_toolkit.logging] '
#                   'Log level is INFO\n'
#                   '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Destination is '
#                   'analysis=5fb6f7a8b116da9bc035f134\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"bids_app_args="\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"example-bool-param=False"\n'
#                   '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"example-empty-param="\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"example-threshold=3.1415926"\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"gear-dry-run=False"\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"gear-ignore-bids-errors=False"\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"gear-intermediate-files="\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"gear-intermediate-folders="\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"gear-keep-output=False"\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"gear-log-level=INFO"\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"gear-run-bids-validation=True"\n'
#                   '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"gear-save-intermediate-output=False"\n'
#                   '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"verbose=v"\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:35     INFO '
#                   'flywheel_gear_toolkit.context.context] Config '
#                   '"write-graph=False"\n'},
#           {'fd': 2,
#            'msg': '/usr/local/miniconda/lib/python3.8/site-packages/flywheel/flywheel.py:6215: '
#                   'UserWarning: Client version 14.3.3 does not match server '
#                   'version 12.4.5. Please update your client version!\n'
#                   "  warnings.warn('Client version {} does not match server "
#                   'version {}. Please update your client '
#                   "version!'.format(SDK_VERSION, release_version))\n"},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36  WARNING Flywheel] Use "pip install '
#                   'flywheel-sdk~=12.4.5" to install a compatible version for '
#                   'this server\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO utils.bids.run_level] Gear run '
#                   "level and hierarchy labels: {'run_level': 'subject', "
#                   "'run_label': 'sub-TOME3024', 'group': 'scien', "
#                   "'project_label': 'BIDS_multi_session', 'subject_label': "
#                   "'sub-TOME3024', 'session_label': None, 'acquisition_label': "
#                   'None}\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO '
#                   'utils.fly.set_performance_config] os.cpu_count() = 4\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO '
#                   'utils.fly.set_performance_config] using n_cpus = 4 (maximum '
#                   'available)\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO '
#                   'utils.fly.set_performance_config] '
#                   'psutil.virtual_memory().available= 14.00 GiB\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO '
#                   'utils.fly.set_performance_config] using mem_gb = 14 '
#                   '(maximum available)\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO utils.freesurfer] Using '
#                   'FreeSurfer license in project info.\n'},
#           {'fd': 1, 'msg': 'num_things = None\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36  WARNING '
#                   'flywheel_gear_toolkit.interfaces.command_line] Removing '
#                   'parameter with empty value for key "example-bool-param".\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36  WARNING '
#                   'flywheel_gear_toolkit.interfaces.command_line] Removing '
#                   'parameter with empty value for key '
#                   '"example-empty-param".\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36  WARNING '
#                   'flywheel_gear_toolkit.interfaces.command_line] Removing '
#                   'parameter with empty value for key "write-graph".\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO __main__] command is: '
#                   "['./tests/test.sh', '/flywheel/v0/work/bids', "
#                   "'/flywheel/v0/output/5fb6f7a8b116da9bc035f134', "
#                   "'participant', '', '--example-threshold=3.1415926', '-v', "
#                   "'--n_cpus=4', '--mem_gb=14']\n"},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO utils.bids.download_run_level] '
#                   'Not downloading source data.\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO utils.bids.download_run_level] '
#                   'Dry run is NOT set.  Data WILL be downloaded.\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO utils.bids.download_run_level] '
#                   'Downloading BIDS data in all folders.\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO utils.bids.download_run_level] '
#                   'Downloading BIDS for subject "sub-TOME3024"\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:36     INFO '
#                   'flywheel_gear_toolkit.context.context] Using source '
#                   'container: project=5dc091c169d4f3002d16f32f\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:37     INFO bids-exporter] Processing '
#                   'project files\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:37     INFO bids-exporter] Processing '
#                   'session files\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:37     INFO bids-exporter] Processing '
#                   'acquisition files\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:37     INFO bids-exporter] Processing '
#                   'acquisition files\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:37     INFO bids-exporter] Processing '
#                   'acquisition files\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:37     INFO bids-exporter] Downloading '
#                   'project files\n'
#                   '[ 20201119 22:54:37     INFO bids-exporter] Downloading '
#                   'session files\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:37     INFO bids-exporter] Downloading '
#                   'acquisition files\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:37     INFO bids-exporter] Downloading '
#                   'acquisition file: '
#                   'sub-TOME3024_ses-Session1_dir-PA_epi.nii.gz\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:37     INFO bids-exporter] Downloading '
#                   'acquisition file: '
#                   'sub-TOME3024_ses-Session1_dir-AP_epi.nii.gz\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:38     INFO bids-exporter] Downloading '
#                   'acquisition file: '
#                   'sub-TOME3024_ses-Session1_task-REST_dir-AP_run-1_sbref.nii.gz\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:38     INFO bids-exporter] Downloading '
#                   'acquisition file: '
#                   'sub-TOME3024_ses-Session1_task-REST_dir-AP_run-2_bold.nii.gz\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52     INFO bids-exporter] Downloading '
#                   'acquisition file: '
#                   'sub-TOME3024_ses-Session2_acq-MPR_T1w.nii.gz\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52     INFO bids-exporter] Creating '
#                   'sidecar files\n'
#                   '[ 20201119 22:54:52     INFO bids-exporter] Creating '
#                   'sidecar file: '
#                   '/flywheel/v0/work/bids/dataset_description.json\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52     INFO bids-exporter] Creating '
#                   'sidecar file: '
#                   '/flywheel/v0/work/bids/sub-TOME3024/ses-Session1/fmap/sub-TOME3024_ses-Session1_dir-PA_epi.nii.gz\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52     INFO bids-exporter] Creating '
#                   'sidecar file: '
#                   '/flywheel/v0/work/bids/sub-TOME3024/ses-Session1/fmap/sub-TOME3024_ses-Session1_dir-AP_epi.nii.gz\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52     INFO bids-exporter] Creating '
#                   'sidecar file: '
#                   '/flywheel/v0/work/bids/sub-TOME3024/ses-Session1/func/sub-TOME3024_ses-Session1_task-REST_dir-AP_run-1_sbref.nii.gz\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52     INFO bids-exporter] Creating '
#                   'sidecar file: '
#                   '/flywheel/v0/work/bids/sub-TOME3024/ses-Session1/func/sub-TOME3024_ses-Session1_task-REST_dir-AP_run-2_bold.nii.gz\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52     INFO bids-exporter] Creating '
#                   'sidecar file: '
#                   '/flywheel/v0/work/bids/sub-TOME3024/ses-Session2/anat/sub-TOME3024_ses-Session2_acq-MPRHA_T1w.nii.gz\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52     INFO utils.bids.download_run_level] '
#                   'Found BIDS path /flywheel/v0/work/bids\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52     INFO utils.bids.download_run_level] '
#                   "type of Funding is: <class 'str'>\n"},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52  WARNING utils.bids.download_run_level] '
#                   'data["Funding"] is not a list\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52     INFO utils.bids.download_run_level] '
#                   "changed it to: <class 'list'>\n"},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:52     INFO utils.bids.validate] Command: '
#                   'bids-validator --verbose --json /flywheel/v0/work/bids\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO utils.bids.validate] '
#                   'bids-validator return code: 0\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO utils.bids.validate] '
#                   'bids-validator results:\n'
#                   '\n'
#                   'Valid BIDS files summary:\n'
#                   "{       'dataProcessed': False,\n"
#                   "        'modalities': ['sbref', 'bold', 'T1w', "
#                   "'fieldmap'],\n"
#                   "        'sessions': ['Session1', 'Session2'],\n"
#                   "        'size': 560115759,\n"
#                   "        'subjects': ['TOME3024'],\n"
#                   "        'tasks': ['REST'],\n"
#                   "        'totalFiles': 11}\n"
#                   '\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55  WARNING utils.bids.validate] Task '
#                   'scans should have a corresponding events.tsv file. If this '
#                   'is a resting state scan you can ignore this warning or '
#                   'rename the task to include the word "rest".\n'
#                   '      '
#                   '/sub-TOME3024/ses-Session1/func/sub-TOME3024_ses-Session1_task-REST_dir-AP_run-2_bold.nii.gz\n'
#                   '\n'
#                   '[ 20201119 22:54:55  WARNING utils.bids.validate] The '
#                   'recommended file /README is missing. See Section 03 '
#                   '(Modality agnostic files) of the BIDS specification.\n'
#                   '\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55  WARNING utils.bids.validate] The '
#                   'Authors field of dataset_description.json should contain an '
#                   'array of fields - with one author per field. This was '
#                   'triggered because there are no authors, which will make DOI '
#                   'registration from dataset metadata impossible.\n'
#                   '\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO utils.bids.download_run_level] '
#                   'Downloading BIDS data was successful!\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO utils.bids.tree] Getting '
#                   '"tree" listing of /flywheel/v0/work/bids/\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO utils.bids.tree] Wrote '
#                   '"/flywheel/v0/output/bids_tree.html"\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO __main__] Creating output '
#                   'directory /flywheel/v0/output/5fb6f7a8b116da9bc035f134\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO '
#                   'flywheel_gear_toolkit.interfaces.command_line] Executing '
#                   'command: \n'
#                   ' ./tests/test.sh /flywheel/v0/work/bids '
#                   '/flywheel/v0/output/5fb6f7a8b116da9bc035f134 participant  '
#                   '--example-threshold=3.1415926 -v --n_cpus=4 --mem_gb=14 \n'
#                   '\n'
#                   '\n'},
#           {'fd': 1, 'msg': 'Python 3.9.0\n\n'},
#           {'fd': 1,
#            'msg': 'add html files to find in '
#                   '/flywheel/v0/output/5fb6f7a8b116da9bc035f134\n'
#                   '\n'},
#           {'fd': 1, 'msg': 'ls \n\n'},
#           {'fd': 1,
#            'msg': 'Dockerfile\n'
#                   '\n'
#                   'LICENSE\n'
#                   '\n'
#                   'README.md\n'
#                   '\n'
#                   'config.json\n'
#                   '\n'
#                   'manifest.json\n'
#                   '\n'
#                   'output\n'
#                   '\n'
#                   'requirements.txt\n'
#                   '\n'
#                   'run.py\n'
#                   '\n'
#                   'setup.cfg\n'
#                   '\n'
#                   'tests\n'
#                   '\n'
#                   'utils\n'
#                   '\n'
#                   'work\n'
#                   '\n'},
#           {'fd': 1,
#            'msg': 'arguments: /flywheel/v0/work/bids '
#                   '/flywheel/v0/output/5fb6f7a8b116da9bc035f134 participant '
#                   '--example-threshold=3.1415926 -v --n_cpus=4 --mem_gb=14\n'
#                   '\n'
#                   '--example-threshold=3.1415926 -v --n_cpus=4\n'
#                   '\n'},
#           {'fd': 1, 'msg': 'I will not generate an error\n\n'},
#           {'fd': 1, 'msg': 'test.sh is done\n'},
#           {'fd': 1, 'msg': '\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO '
#                   'flywheel_gear_toolkit.interfaces.command_line] Command '
#                   'return code: 0\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO '
#                   'flywheel_gear_toolkit.utils.zip_tools] Zipping output file '
#                   'bids-app-template_sub-TOME3024_5fb6f7a8b116da9bc035f134.zip\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO utils.results.zip_htmls] '
#                   'Creating viewable archives for all html files\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO utils.results.zip_htmls] Found '
#                   'path: /flywheel/v0/output/5fb6f7a8b116da9bc035f134\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO utils.results.zip_htmls] Found '
#                   'index.html\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO utils.results.zip_htmls] '
#                   'Creating viewable archive '
#                   '"/flywheel/v0/output/index_5fb6f7a8b116da9bc035f134.html.zip"\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO utils.results.zip_htmls] '
#                   'Creating viewable archive '
#                   '"/flywheel/v0/output/bids_tree_5fb6f7a8b116da9bc035f134.html.zip"\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO __main__] Wrote '
#                   '/flywheel/v0/output/.metadata.json\n'},
#           {'fd': 1,
#            'msg': '[ 20201119 22:54:55     INFO __main__] '
#                   'flywheel-apps/bids-app-template] Gear is done.  Returning '
#                   '0\n'},
#           {'fd': -1,
#            'msg': 'Gear completed successfully after running for 20.352s.\n'},
#           {'fd': -1, 'msg': 'Uploading results...\n'},
#           {'fd': -1, 'msg': 'Job complete.\n'},
#           {'fd': -1, 'msg': 'The following outputs have been saved:\n'},
#           {'fd': -1, 'msg': '  - index_5fb6f7a8b116da9bc035f134.html.zip\n'},
#           {'fd': -1,
#            'msg': '  - '
#                   'bids-app-template_sub-TOME3024_5fb6f7a8b116da9bc035f134.zip\n'},
#           {'fd': -1, 'msg': '  - bids_tree.html\n'},
#           {'fd': -1,
#            'msg': '  - bids_tree_5fb6f7a8b116da9bc035f134.html.zip\n'}]}
